# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Econ441B/Fatalities.csv")

# %%
import seaborn as sns

# %%
sns.lmplot(data = df, x = "income", y = "spirits",line_kws= {"color":"red"}, height = 7, aspect = 1)

# %% [markdown]
# The above graph explain the realation ship between spirits consumption and inocme, we can see that a positive relation ship exist between income and spirit consumption
